# %% [markdown]
# # Relátorio de Análise Vll

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep =';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor metro quadarado bruto Tipo Agregado
# 0   1700.0       500.0    60.0                    56.500000   Apartamento
# 1   7000.0         0.0     0.0                    70.000000          Casa
# 2   5200.0      4020.0  1111.0                    68.873333   Apartamento
# 3    800.0       390.0    20.0                    80.666667   Apartamento
# 4    800.0       230.0     0.0                    21.458333   Apartamento
# 5   1300.0       301.0    17.0                    32.360000   Apartamento
# 6  22000.0         0.0     0.0                    29.333333          Casa
# 7   1000.0         0.0     0.0                    15.384615          Casa
# 8  35000.0     19193.0  3030.0                    82.335252   Apartamento
# 9   1500.0       642.0    74.0                    31.657143   Apartamento

# %%
dados['Valor'].mean()
# Out:
# 13177.971364681036

# %%
dados['Bairro'].unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Barra da Tijuca', 'Centro',
#        'Higienópolis', 'Cachambi', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Botafogo', 'Taquara',
#        'Freguesia (Jacarepaguá)', 'Tijuca', 'Olaria', 'Leblon',
#        'São Cristóvão', 'Ipanema', 'Campo Grande',
#        'Recreio dos Bandeirantes', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Vargem Grande', 'São Conrado', 'Maria da Graça', 'Vila Valqueire',
#        'Gávea', 'Cosme Velho', 'Bonsucesso', 'Todos os Santos',
#        'Laranjeiras', 'Itanhangá', 'Flamengo', 'Piedade', 'Lagoa',
#        'Santo Cristo', 'Largo do Machado', 'Catete', 'Jardim Carioca',
#        'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel',
#        'Quintino Bocaiúva', 'São Francisco Xavier', 'Engenho Novo',
#        'Engenho de Dentro', 'Pilares', 'Cidade Nova', 'Arpoador',
#        'Água Santa', 'Ilha do Governador', 'Jardim Sulacap',
#        'Del Castilho', 'Oswaldo Cruz', 'Vila da Penha', 'Anil', 'Tanque',
#        'Vaz Lobo', 'Madureira', 'Pechincha', 'Leme', 'Irajá', 'Andaraí',
#        'Cordovil', 'Urca', 'Penha', 'Vigário Geral', 'Gardênia Azul',
#        'Santa Cruz', 'Rio Comprido', 'Santa Teresa', 'Inhaúma',
#        'Marechal Hermes', 'Pavuna', 'Curicica', 'Santíssimo', 'Moneró',
#        'Vila Militar', 'Camorim', 'Cascadura', 'Manguinhos',
#        'Praia da Bandeira', 'Saúde', 'Joá', 'Gamboa', 'Bangu', 'Realengo',
#        'Fátima', 'Jardim Guanabara', 'Inhoaíba', 'Rocha', 'Jabour',
#        'Parada de Lucas', 'Braz de Pina', 'Vila Kosmos',
#        'Praça da Bandeira', 'Vista Alegre', 'Encantado', 'Campinho',
#        'Penha Circular', 'Guaratiba', 'Lapa', 'Riachuelo', 'Portuguesa',
#        'Vicente de Carvalho', 'Catumbi', 'Castelo', 'Abolição',
#        'Tomás Coelho', 'Colégio', 'Caju', 'Alto da Boa Vista',
#        'Bento Ribeiro', 'Estácio', 'Jardim América', 'Paciência',
#        'Pedra de Guaratiba', 'Padre Miguel', 'Guadalupe', 'Zumbi',
#        'Sampaio', 'Anchieta', 'Tauá', 'Icaraí', 'Cinelândia',
#        'Senador Vasconcelos', 'Rocha Miranda', 'Barra de Guaratiba',
#        'Paquetá', 'Senador Camará', 'Freguesia (Ilha do Governador)',
#        'Parque Anchieta', 'Honório Gurgel', 'Turiaçu', 'Cosmos',
#        'Pitangueiras', 'Vidigal', 'Usina', 'Cacuia', 'Ribeira', 'Jacaré',
#        'Cocotá', 'Engenho da Rainha', 'Cachamorra', 'Itaguaí',
#        'Ricardo de Albuquerque', 'Cavalcanti', 'Cidade de Deus',
#        'Magalhães Bastos', 'Coelho Neto', 'Vasco da Gama', 'Bancários',
#        'Rio da Prata', 'Cidade Jardim', 'Parque Colúmbia', 'Sepetiba'],
#       dtype=object)

# %%
# Qual valor medio do bairro
bairros = ['Copacabana', 'Jardim Botânico', 'Barra da Tijuca', 'Centro',
       'Higienópolis']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0         Copacabana
# 1    Jardim Botânico
# 2    Barra da Tijuca
# 3             Centro
# 4       Higienópolis
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [2, 6, 18, 20, 28, 33, 39, 42, 47, 57, 58, 75, 78, 86, 87, 90, 94, 100, 101, 108, 109, 111, 130, 142, 151, 152, 153, 154, 155, 159, 161, 163, 167, 171, 174, 187, 191, 193, 197, 219, 222, 224, 241, 242, 245, 249, 253, 254, 266, 268, 272, 296, 305, 315, 320, 322, 330, 337, 338, 344, 348, 354, 358, 364, 377, 380, 389, 391, 397, 405, 408, 423, 429, 430, 431, 433, 441, 444, 445, 454, 459, 460, 482, 488, 494, 498, 501, 502, 511, 519, 533, 535, 543, 547, 555, 562, 570, 572, 573, 578, ...], 'Centro': [3, 8, 36, 43, 44, 50, 52, 70, 83, 84, 91, 97, 102, 105, 123, 124, 132, 140, 157, 169, 173, 181, 214, 233, 234, 235, 236, 246, 262, 269, 275, 277, 297, 309, 318, 323, 327, 328, 346, 363, 369, 370, 372, 383, 384, 393, 406, 426, 434, 443, 446, 451, 461, 467, 469, 489, 522, 551, 556, 568, 626, 645, 647, 671, 678, 681, 694, 700, 735, 738, 756, 775, 778, 787, 808, 836, 837, 843, 856, 862, 863, 885, 893, 904, 906, 912, 929, 932, 950, 952, 954, 956, 966, 970, 973, 975, 977, 986, 991, 1002, ...], 'Copacabana': [0, 11, 12, 13, 31, 32, 37, 41, 56, 119, 128, 148, 158, 184, 190, 203, 204, 207, 209, 213, 220, 237, 244, 255, 265, 276, 281, 293, 319, 361, 388, 407, 410, 415, 427, 428, 442, 453, 468, 473, 475, 485, 490, 514, 530, 542, 552, 553, 571, 585, 597, 624, 625, 632, 638, 641, 667, 670, 680, 711, 712, 713, 714, 728, 739, 776, 779, 783, 807, 821, 841, 842, 849, 858, 867, 895, 899, 901, 907, 934, 936, 961, 980, 987, 988, 993, 1004, 1017, 1020, 1026, 1036, 1053, 1079, 1089, 1094, 1137, 1146, 1179, 1194, 1206, ...], 'Higienópolis': [4, 1115, 1419, 3105, 3219, 5013, 5873, 6520, 11895, 12836, 13497, 14605, 16728, 16932, 19391, 21023, 22453, 25040, 25120, 26678, 27270, 27339, 28596, 28708, 28777], 'Jardim Botânico': [1, 51, 73, 76, 457, 478, 518, 651, 652, 719, 723, 813, 835, 949, 1000, 1192, 1382, 1445, 1726, 1766, 1983, 2019, 2191, 2635, 2785, 2802, 3033, 3048, 3107, 3136, 3199, 3322, 3585, 3692, 3739, 3744, 3850, 4024, 4053, 4082, 4095, 4153, 4160, 4212, 4217, 4803, 5041, 5195, 5206, 5215, 5368, 5444, 5606, 5647, 5674, 5957, 6075, 6103, 6108, 6188, 6353, 6693, 6734, 6786, 6854, 7023, 7031, 7149, 7274, 7310, 7347, 7479, 7518, 7616, 7667, 7746, 7800, 7852, 7896, 7950, 8010, 8077, 8101, 8135, 8407, 8515, 8576, 8730, 8769, 8857, 8937, 9449, 9525, 9630, 9710, 9762, 9803, 9999, 10053, 10136, ...]}

# %%
for bairro, dados in grupo_bairro:
  print(dados)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 6           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 18                 Apartamento  Barra da Tijuca        2      1       1    67
# 20          Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 28                 Apartamento  Barra da Tijuca        3      3       1   175
# ...                        ...              ...      ...    ...     ...   ...
# 32178              Apartamento  Barra da Tijuca        2      1       1    85
# 32179              Apartamento  Barra da Tijuca        3      2       0    98
# 32180  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32181              Apartamento  Barra da Tijuca        3      2       2   140
# 32190       Casa de Condomínio  Barra da Tijuca        5      3       4   450
#
#          Valor  Condominio    IPTU  Valor metro quadarado bruto Tipo Agregado
# 2       5200.0      4020.0  1111.0                    68.873333   Apartamento
# 6      22000.0         0.0     0.0                    29.333333          Casa
# 18      1700.0       589.0   147.0                    36.358209   Apartamento
# 20      7500.0      2695.0     0.0                    21.877682          Casa
# 28      4200.0      1500.0   500.0                    35.428571   Apartamento
# ...        ...         ...     ...                          ...           ...
# 32178   2250.0      1561.0   197.0                    47.152941   Apartamento
# 32179   2300.0       887.0   177.0                    34.326531   Apartamento
# 32180   2000.0      1096.0     0.0                    56.290909   Apartamento
# 32181   5500.0      1900.0   700.0                    57.857143   Apartamento
# 32190  15000.0      1711.0  2332.0                    42.317778          Casa
#
# [6198 rows x 11 columns]
#                           Tipo  Bairro  Quartos  Vagas  Suites  Area  \
# 3                  Apartamento  Centro        1      0       0    15
# 8      Conjunto Comercial/Sala  Centro        0      3       0   695
# 36     Conjunto Comercial/Sala  Centro        0      5       0  1306
# 43     Conjunto Comercial/Sala  Centro        0      0       0   460
# 44     Conjunto Comercial/Sala  Centro        0      0       0  1170
# ...                        ...     ...      ...    ...     ...   ...
# 32184  Conjunto Comercial/Sala  Centro        0      0       0   140
# 32186  Conjunto Comercial/Sala  Centro        0      0       0    32
# 32192              Box/Garagem  Centro        0      0       0   755
# 32193                Quitinete  Centro        0      0       0    27
# 32197  Conjunto Comercial/Sala  Centro        0      0       0   250
#
#           Valor  Condominio    IPTU  Valor metro quadarado bruto Tipo Agregado
# 3         800.0       390.0    20.0                    80.666667   Apartamento
# 8       35000.0     19193.0  3030.0                    82.335252   Apartamento
# 36     117540.0     19486.0     0.0                   104.920368   Apartamento
# 43       7500.0      4797.0  2019.0                    31.121739   Apartamento
# 44     140456.0     23409.0  5852.0                   145.057265   Apartamento
# ...         ...         ...     ...                          ...           ...
# 32184    4000.0      1412.0   496.0                    42.200000   Apartamento
# 32186     600.0      1035.0    83.0                    53.687500   Apartamento
# 32192   14000.0         0.0     0.0                    18.543046   Apartamento
# 32193     800.0       350.0    25.0                    43.518519   Apartamento
# 32197    6500.0      4206.0  1109.0                    47.260000   Apartamento
#
# [3253 rows x 11 columns]
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0        Quitinete  Copacabana        1      0       0    40   1700.0
# 11     Apartamento  Copacabana        1      0       1    40   2000.0
# 12       Quitinete  Copacabana        1      0       0    27   1800.0
# 13     Apartamento  Copacabana        4      3       1   243  13000.0
# 31     Apartamento  Copacabana        3      1       2   378  10000.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 32138  Apartamento  Copacabana        1      0       0    60   2400.0
# 32154  Apartamento  Copacabana        2      0       0    67   2450.0
# 32174  Apartamento  Copacabana        2      0       1    70   4100.0
# 32176  Apartamento  Copacabana        1      0       0    50   1950.0
# 32183    Quitinete  Copacabana        1      0       0    22   1500.0
#
#        Condominio   IPTU  Valor metro quadarado bruto Tipo Agregado
# 0           500.0   60.0                    56.500000   Apartamento
# 11          561.0   50.0                    65.275000   Apartamento
# 12          501.0    0.0                    85.222222   Apartamento
# 13         2000.0  803.0                    65.032922   Apartamento
# 31         2150.0  700.0                    33.994709   Apartamento
# ...           ...    ...                          ...           ...
# 32138       530.0   78.0                    50.133333   Apartamento
# 32154       679.0   80.0                    47.895522   Apartamento
# 32174       700.0   90.0                    69.857143   Apartamento
# 32176       450.0   70.0                    49.400000   Apartamento
# 32183       286.0  200.0                    90.272727   Apartamento
#
# [3070 rows x 11 columns]
#                           Tipo        Bairro  Quartos  Vagas  Suites  Area  \
# 4                  Apartamento  Higienópolis        1      0       0    48
# 1115               Apartamento  Higienópolis        1      0       0    55
# 1419               Apartamento  Higienópolis        1      0       1    45
# 3105               Apartamento  Higienópolis        2      0       1    48
# 3219               Apartamento  Higienópolis        1      0       1    37
# 5013               Apartamento  Higienópolis        2      0       0    60
# 5873                Loja/Salão  Higienópolis        0      0       0    61
# 6520                      Casa  Higienópolis        3      5       0   250
# 11895              Apartamento  Higienópolis        2      0       0    52
# 12836  Galpão/Depósito/Armazém  Higienópolis        0      0       0   542
# 13497              Apartamento  Higienópolis        3      0       0    70
# 14605  Galpão/Depósito/Armazém  Higienópolis        0      0       0    71
# 16728              Apartamento  Higienópolis        2      1       0    88
# 16932           Prédio Inteiro  Higienópolis        0      0       0   600
# 19391           Prédio Inteiro  Higienópolis        0      0       0  1092
# 21023              Apartamento  Higienópolis        1      0       0    45
# 22453              Apartamento  Higienópolis        2      0       0    52
# 25040              Apartamento  Higienópolis        2      0       0    65
# 25120              Apartamento  Higienópolis        2      1       0    68
# 26678  Galpão/Depósito/Armazém  Higienópolis        0      0       0   782
# 27270           Casa Comercial  Higienópolis        0      2       0   210
# 27339                Quitinete  Higienópolis        1      0       0    96
# 28596              Apartamento  Higienópolis        3      0       0   100
# 28708  Conjunto Comercial/Sala  Higienópolis        0      0       0    35
# 28777           Prédio Inteiro  Higienópolis        0      0       0  2717
#
#          Valor  Condominio    IPTU  Valor metro quadarado bruto Tipo Agregado
# 4        800.0       230.0     0.0                    21.458333   Apartamento
# 1115     750.0       120.0     0.0                    15.818182   Apartamento
# 1419     800.0       120.0    31.0                    21.133333   Apartamento
# 3105    1100.0       200.0     0.0                    27.083333   Apartamento
# 3219     900.0       308.0     0.0                    32.648649   Apartamento
# 5013     850.0       230.0     0.0                    18.000000   Apartamento
# 5873    1500.0         0.0    62.0                    25.606557   Apartamento
# 6520    2400.0         0.0   650.0                    12.200000          Casa
# 11895    800.0       200.0     0.0                    19.230769   Apartamento
# 12836   6000.0         0.0   717.0                    12.392989   Apartamento
# 13497    900.0       180.0     0.0                    15.428571   Apartamento
# 14605   2500.0         0.0    60.0                    36.056338   Apartamento
# 16728   1100.0       400.0    44.0                    17.545455   Apartamento
# 16932   6500.0         0.0  4306.0                    18.010000   Apartamento
# 19391  10000.0         0.0  1800.0                    10.805861   Apartamento
# 21023    700.0       130.0     0.0                    18.444444   Apartamento
# 22453    800.0       200.0     0.0                    19.230769   Apartamento
# 25040   1100.0        90.0     0.0                    18.307692   Apartamento
# 25120   1200.0       380.0     0.0                    23.235294   Apartamento
# 26678   9000.0         0.0  1172.0                    13.007673   Apartamento
# 27270   1900.0         0.0     0.0                     9.047619   Apartamento
# 27339    700.0         0.0     0.0                     7.291667   Apartamento
# 28596   1200.0       180.0    21.0                    14.010000   Apartamento
# 28708    750.0         0.0    19.0                    21.971429   Apartamento
# 28777  20000.0         0.0     0.0                     7.361060   Apartamento
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 1                         Casa  Jardim Botânico        2      0       1   100
# 51     Conjunto Comercial/Sala  Jardim Botânico        0      1       0    50
# 73                 Apartamento  Jardim Botânico        2      2       0    95
# 76     Conjunto Comercial/Sala  Jardim Botânico        0      1       0    24
# 457                       Casa  Jardim Botânico        2      4       1   107
# ...                        ...              ...      ...    ...     ...   ...
# 31805              Apartamento  Jardim Botânico        2      1       1    79
# 31944               Loja/Salão  Jardim Botânico        0     23       0   582
# 31962              Apartamento  Jardim Botânico        3      0       1   360
# 32106  Conjunto Comercial/Sala  Jardim Botânico        1      3       0   500
# 32158              Apartamento  Jardim Botânico        3      1       2   145
#
#           Valor  Condominio    IPTU  Valor metro quadarado bruto Tipo Agregado
# 1        7000.0         0.0     0.0                    70.000000          Casa
# 51       4000.0      1160.0   200.0                   107.200000   Apartamento
# 73       4000.0      1170.0     0.0                    54.421053   Apartamento
# 76       2500.0       682.0   112.0                   137.250000   Apartamento
# 457      9500.0         0.0  1091.0                    98.981308          Casa
# ...         ...         ...     ...                          ...           ...
# 31805    3300.0       965.0   210.0                    56.645570   Apartamento
# 31944  120000.0      3800.0     0.0                   212.714777   Apartamento
# 31962   17000.0      1700.0  1200.0                    55.277778   Apartamento
# 32106   17000.0         0.0  1000.0                    36.000000   Apartamento
# 32158    5000.0      1296.0   317.0                    45.606897   Apartamento
#
# [347 rows x 11 columns]

# %%
for bairro, data in grupo_bairro:
  print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Barra da Tijuca -> 9035.204743465634
# Centro -> 19021.487857362434
# Copacabana -> 4514.538436482085
# Higienópolis -> 2970.0
# Jardim Botânico -> 8818.530259365994

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                     Valor  Condominio
# Bairro
# Barra da Tijuca   9035.20     3490.42
# Centro           19021.49     4727.99
# Copacabana        4514.54     1183.24
# Higienópolis      2970.00      118.72
# Jardim Botânico   8818.53     1271.80

# %% [markdown]
# ## Estatísticas descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count      mean       std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  6198.0   9035.20  30328.23   100.0  2000.0  3500.0   8000.0
# Centro           3253.0  19021.49  59397.57    90.0  1000.0  3750.0  15000.0
# Copacabana       3070.0   4514.54   6502.57   100.0  1900.0  3000.0   4900.0
# Higienópolis       25.0   2970.00   4425.85   700.0   800.0  1100.0   2400.0
# Jardim Botânico   347.0   8818.53  11723.22  1100.0  3000.0  4000.0   9500.0
#
#                       max
# Bairro
# Barra da Tijuca  738197.0
# Centro           950000.0
# Copacabana       198000.0
# Higienópolis      20000.0
# Jardim Botânico  120000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo    Máximo
# Bairro
# Barra da Tijuca   100.0  738197.0
# Centro             90.0  950000.0
# Copacabana        100.0  198000.0
# Higienópolis      700.0   20000.0
# Jardim Botânico  1100.0  120000.0

# %% [markdown]
# ## Importando matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize =(20,10))

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color= 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Valor'].max().plot.bar(color= 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %% [markdown]
# ## Selecionando as estatísticas descritivas

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto', sort = False)
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2
